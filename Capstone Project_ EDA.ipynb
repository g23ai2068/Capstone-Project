# %% [markdown]
# # Importing Libraries and mounting google drive

# %%
#Importing Libraries
import pandas as pd
import seaborn as sns
import numpy as np

# %%
#Mounting Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # EDA for Calendar.csv

# %%
#Using read_csv method to load the csv file into Pandas Dataframe
calendar = pd.read_csv('/content/drive/MyDrive/Capstone Project/calendar.csv')
calendar
# Out:
# <ipython-input-64-ec600a86982b>:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   calendar = pd.read_csv('/content/drive/MyDrive/Capstone Project/calendar.csv')
#          listing_id         date available    price adjusted_price  \
# 0                958  04-09-2024         t  $170.00            NaN
# 1                958  05-09-2024         f  $170.00            NaN
# 2                958  06-09-2024         f  $170.00            NaN
# 3                958  07-09-2024         f  $170.00            NaN
# 4                958  08-09-2024         f  $170.00            NaN
# ...              ...         ...       ...      ...            ...
# 1048570     36280429  21-06-2025         t  $170.00            NaN
# 1048571     36280429  22-06-2025         t  $170.00            NaN
# 1048572     36280429  23-06-2025         t  $170.00            NaN
# 1048573     36280429  24-06-2025         t  $170.00            NaN
# ...

# %%
#Using shape method to check the number of rows and columns
print('Number of rows:', calendar.shape[0])
print('Number of rows:', calendar.shape[1])
# Out:
# Number of rows: 1048575
# Number of rows: 8

# %%
#Calculating the summary statistics to analyze and gain insights into the data values present in the calendar CSV file
calendar.describe()
# Out:
#         listing_id   minimum_nights  maximum_nights  available_unit
# count  1.048575e+06    1.048575e+06    1.048575e+06    1.048575e+06
# mean   1.621502e+07    2.411912e+01    7.476192e+06    5.499246e+00
# std    1.147135e+07    5.851778e+01    1.264793e+08    2.872590e+00
# min    9.580000e+02    1.000000e+00    1.000000e+00    1.000000e+00
# 25%    5.094146e+06    2.000000e+00    6.000000e+01    3.000000e+00
# 50%    1.606850e+07    5.000000e+00    9.990000e+02    6.000000e+00
# 75%    2.591230e+07    3.000000e+01    1.125000e+03    8.000000e+00
# max    3.628043e+07    1.125000e+03    2.147484e+09    1.000000e+01

# %%
# Generating an informational table of the calendar CSV file in order to better understand the data types, null count of each column.
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 8 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   listing_id      1048575 non-null  int64
#  1   date            1048575 non-null  object
#  2   available       1048575 non-null  object
#  3   price           1048575 non-null  object
#  4   adjusted_price  730 non-null      object
#  5   minimum_nights  1048575 non-null  int64
#  6   maximum_nights  1048575 non-null  int64
#  7   available_unit  1048575 non-null  int64
# dtypes: int64(4), object(4)
# memory usage: 64.0+ MB

# %%
# Listing all the column names present in Calendar CSV
calendar.columns
# Out:
# Index(['listing_id ', 'date', 'available', 'price', 'adjusted_price',
#        'minimum_nights', 'maximum_nights', 'available_unit'],
#       dtype='object')

# %%
# Identifying columns that contain null values in the dataset.
calendar.isnull().sum()
# Out:
# listing_id              0
# date                    0
# available               0
# price                   0
# adjusted_price    1047845
# minimum_nights          0
# maximum_nights          0
# available_unit          0
# dtype: int64

# %%
# All the values in 'adjusted_price' columns are null hence we can completely get rid of this column
# Dropping 'adjusted_price' from the csv
calendar1 = calendar.drop(columns=['adjusted_price'])
calendar1
# Out:
#          listing_id         date available    price  minimum_nights  \
# 0                958  04-09-2024         t  $170.00               2
# 1                958  05-09-2024         f  $170.00               2
# 2                958  06-09-2024         f  $170.00               2
# 3                958  07-09-2024         f  $170.00               2
# 4                958  08-09-2024         f  $170.00               2
# ...              ...         ...       ...      ...             ...
# 1048570     36280429  21-06-2025         t  $170.00              30
# 1048571     36280429  22-06-2025         t  $170.00              30
# 1048572     36280429  23-06-2025         t  $170.00              30
# 1048573     36280429  24-06-2025         t  $170.00              30
# 1048574     36280429  25-06-2025         t  $170.00              30
#
#          maximum_nights  available_unit
# 0                  1125               8
# 1                  1125               6
# ...

# %%
#Replacing t and f values in available column with True and False
calendar1['available'].replace(['t'], 'True', inplace=True)
calendar1['available'].replace(['f'], 'False', inplace=True)
calendar1
# Out:
#          listing_id         date available    price  minimum_nights  \
# 0                958  04-09-2024      True  $170.00               2
# 1                958  05-09-2024     False  $170.00               2
# 2                958  06-09-2024     False  $170.00               2
# 3                958  07-09-2024     False  $170.00               2
# 4                958  08-09-2024     False  $170.00               2
# ...              ...         ...       ...      ...             ...
# 1048570     36280429  21-06-2025      True  $170.00              30
# 1048571     36280429  22-06-2025      True  $170.00              30
# 1048572     36280429  23-06-2025      True  $170.00              30
# 1048573     36280429  24-06-2025      True  $170.00              30
# 1048574     36280429  25-06-2025      True  $170.00              30
#
#          maximum_nights  available_unit
# 0                  1125               8
# 1                  1125               6
# ...

# %% [markdown]
# # EDA for Listing.csv

# %%
#Using read_csv method to load the csv file into Pandas Dataframe
listing = pd.read_csv('/content/drive/MyDrive/Capstone Project/listing.csv')
listing
# Out:
#                       id                                              name  \
# 0                  26488                 Embarcadero High Rise with Views!
# 1     639252492437720512   Civic Center/Union Square Studio - Convenience!
# 2     650715822075172454      Stylish Apartment in the Heart of Noe Valley
# 3     662392806641687113                                Donatello Hotel, ;
# 4     667349567026153723      Private Bed/Bath/Entrance in modern SF house
# ...                  ...                                               ...
# 7802  769894881482542028  Inn at the Opera San Francisco 1BR unit Sleeps 4
# 7803  769925696894141350           Cozy 2BR Retreat with Parking & Laundry
# 7804  771244981032665581  Forested 3BR Craftsman in Heart of San Francisco
# 7805  773289547346766980                    R1- Cozy stay near Balboa Bart
# 7806  774304380267401610                   JPM Deluxe Union Square Suite 2
#
# ...

# %%
#Using shape method to check the number of rows and columns
print('Number of rows:', listing.shape[0])
print('Number of rows:', listing.shape[1])
# Out:
# Number of rows: 7807
# Number of rows: 18

# %%
#Calculating the summary statistics to analyze and gain insights into the data values present in the calendar CSV file
listing.describe()
# Out:
#                  id       host_id  neighbourhood_group     latitude  \
# count  7.807000e+03  7.807000e+03                  0.0  7807.000000
# mean   3.947473e+17  1.583469e+08                  NaN    37.769485
# std    4.729580e+17  1.898653e+08                  NaN     0.023051
# min    9.580000e+02  1.169000e+03                  NaN    37.708540
# 25%    2.280787e+07  7.197110e+06                  NaN    37.754360
# 50%    4.921290e+07  5.835076e+07                  NaN    37.774900
# 75%    8.833418e+17  2.930250e+08                  NaN    37.788415
# max    1.237237e+18  5.993102e+08                  NaN    37.810943
#
#          longitude         price  minimum_nights  number_of_reviews  \
# count  7807.000000   6158.000000     7807.000000        7807.000000
# mean   -122.429948    239.665313       20.695017          50.334187
# std       0.026965   1000.078707       48.701853         106.163371
# min    -122.512460     25.000000        1.000000           0.000000
# ...

# %%
# Generating an informational table of the calendar CSV file in order to better understand the data types, null count of each column.
listing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7807 entries, 0 to 7806
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              7807 non-null   int64
#  1   name                            7807 non-null   object
#  2   host_id                         7807 non-null   int64
#  3   host_name                       7807 non-null   object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   7807 non-null   object
#  6   latitude                        7807 non-null   float64
#  7   longitude                       7807 non-null   float64
#  8   room_type                       7807 non-null   object
#  9   price                           6158 non-null   float64
#  10  minimum_nights                  7807 non-null   int64
#  11  number_of_reviews               7807 non-null   int64
# ...

# %%
# Listing all the column names present in Calendar CSV
listing.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
# Identifying columns that contain null values in the dataset.
listing.isnull().sum()
# Out:
# id                                   0
# name                                 0
# host_id                              0
# host_name                            0
# neighbourhood_group               7807
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                             1649
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       1771
# reviews_per_month                 1771
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# license                           2878
# dtype: int64

# %% [markdown]
# # EDA for Neighbourhood.csv

# %%
#Using read_csv method to load the csv file into Pandas Dataframe
neighbourhoods = pd.read_csv('/content/drive/MyDrive/Capstone Project/neighbourhoods.csv')
neighbourhoods
# Out:
#     neighbourhood_group          neighbourhood
# 0                   NaN                Bayview
# 1                   NaN         Bernal Heights
# 2                   NaN    Castro/Upper Market
# 3                   NaN              Chinatown
# 4                   NaN         Crocker Amazon
# 5                   NaN        Diamond Heights
# 6                   NaN  Downtown/Civic Center
# 7                   NaN              Excelsior
# 8                   NaN     Financial District
# 9                   NaN              Glen Park
# 10                  NaN       Golden Gate Park
# 11                  NaN         Haight Ashbury
# 12                  NaN         Inner Richmond
# 13                  NaN           Inner Sunset
# 14                  NaN              Lakeshore
# 15                  NaN                 Marina
# 16                  NaN                Mission
# 17                  NaN               Nob Hill
# 18                  NaN             Noe Valley
# ...

# %%
#Using shape method to check the number of rows and columns
print('Number of rows:', neighbourhoods.shape[0])
print('Number of rows:', neighbourhoods.shape[1])
# Out:
# Number of rows: 37
# Number of rows: 2

# %%
#Calculating the summary statistics to analyze and gain insights into the data values present in the calendar CSV file
neighbourhoods.describe()
# Out:
#        neighbourhood_group
# count                  0.0
# mean                   NaN
# std                    NaN
# min                    NaN
# 25%                    NaN
# 50%                    NaN
# 75%                    NaN
# max                    NaN

# %%
# Generating an informational table of the calendar CSV file in order to better understand the data types, null count of each column.
neighbourhoods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   neighbourhood_group  0 non-null      float64
#  1   neighbourhood        37 non-null     object
# dtypes: float64(1), object(1)
# memory usage: 720.0+ bytes

# %%
# Listing all the column names present in Calendar CSV
neighbourhoods.columns
# Out:
# Index(['neighbourhood_group', 'neighbourhood'], dtype='object')

# %%
# Identifying columns that contain null values in the dataset.
neighbourhoods.isnull().sum()
# Out:
# neighbourhood_group    37
# neighbourhood           0
# dtype: int64

# %% [markdown]
# # EDA for Review.csv

# %%
#Using read_csv method to load the csv file into Pandas Dataframe
review = pd.read_csv('/content/drive/MyDrive/Capstone Project/review.csv')
review
# Out:
#                  listing_id        date
# 0                       958  2009-07-23
# 1                       958  2009-08-03
# 2                       958  2009-09-27
# 3                       958  2009-11-05
# 4                       958  2010-02-13
# ...                     ...         ...
# 392954  1219622445222452442  2024-08-24
# 392955  1219622445222452442  2024-08-26
# 392956  1219785829994931401  2024-09-02
# 392957  1233574822709070023  2024-09-02
# 392958  1234136833991870838  2024-09-01
#
# [392959 rows x 2 columns]

# %%
#Using shape method to check the number of rows and columns
print('Number of rows:', review.shape[0])
print('Number of rows:', review.shape[1])
# Out:
# Number of rows: 392959
# Number of rows: 2

# %%
#Calculating the summary statistics to analyze and gain insights into the data values present in the calendar CSV file
review.describe()
# Out:
#          listing_id
# count  3.929590e+05
# mean   8.225927e+16
# std    2.459846e+17
# min    9.580000e+02
# 25%    4.359078e+06
# 50%    1.742188e+07
# 75%    3.680482e+07
# max    1.234137e+18

# %%
# Generating an informational table of the calendar CSV file in order to better understand the data types, null count of each column.
review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392959 entries, 0 to 392958
# Data columns (total 2 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   listing_id  392959 non-null  int64
#  1   date        392959 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 6.0+ MB

# %%
# Listing all the column names present in Calendar CSV
review.columns
# Out:
# Index(['listing_id', 'date'], dtype='object')

# %%
# Identifying columns that contain null values in the dataset.
review.isnull().sum()
# Out:
# listing_id    0
# date          0
# dtype: int64
