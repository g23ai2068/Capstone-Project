# %%
#Importing Libraries
import pandas as pd
import seaborn as sns
import numpy as np

# %%
#Mounting Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Using read_csv method to load the csv file into Pandas Dataframe
calendar = pd.read_csv('/content/drive/MyDrive/Capstone Project/calendar.csv')
calendar.head(1000)
# Out:
# <ipython-input-3-10a8a1acc81a>:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   calendar = pd.read_csv('/content/drive/MyDrive/Capstone Project/calendar.csv')
#      listing_id         date available    price adjusted_price  \
# 0            958  04-09-2024         t  $170.00            NaN
# 1            958  05-09-2024         f  $170.00            NaN
# 2            958  06-09-2024         f  $170.00            NaN
# 3            958  07-09-2024         f  $170.00            NaN
# 4            958  08-09-2024         f  $170.00            NaN
# ..           ...         ...       ...      ...            ...
# 995         8142  27-05-2025         t   $65.00            NaN
# 996         8142  28-05-2025         t   $65.00            NaN
# 997         8142  29-05-2025         t   $65.00            NaN
# 998         8142  30-05-2025         t   $65.00            NaN
# ...

# %%
#Using read_csv method to load the csv file into Pandas Dataframe
listing = pd.read_csv('/content/drive/MyDrive/Capstone Project/listing.csv')
listing.head(1000)
# Out:
#                      id                                             name  \
# 0                 26488                Embarcadero High Rise with Views!
# 1    639252492437720512  Civic Center/Union Square Studio - Convenience!
# 2    650715822075172454     Stylish Apartment in the Heart of Noe Valley
# 3    662392806641687113                               Donatello Hotel, ;
# 4    667349567026153723     Private Bed/Bath/Entrance in modern SF house
# ..                  ...                                              ...
# 995              964751               Fully Private Garden Studio w/bath
# 996              980783                             Potrero Hill Retreat
# 997              991765                   Country living in the Mission!
# 998              998701              Private Room in Ocean Beach Cottage
# 999             1005642                  Walk + Bike + Transit Score 97!
#
#       host_id host_name  neighbourhood_group          neighbourhood  \
# ...

# %%
#Using read_csv method to load the csv file into Pandas Dataframe
review = pd.read_csv('/content/drive/MyDrive/Capstone Project/review.csv')
review.head(1000)
# Out:
#      listing_id        date
# 0           958  2009-07-23
# 1           958  2009-08-03
# 2           958  2009-09-27
# 3           958  2009-11-05
# 4           958  2010-02-13
# ..          ...         ...
# 995       12522  2017-07-16
# 996       12522  2017-08-02
# 997       12522  2017-08-09
# 998       12522  2017-08-15
# 999       12522  2017-08-23
#
# [1000 rows x 2 columns]

# %%
merged_df = pd.concat([calendar, listing, review], axis=1)
merged_df.head(1000)
# Out:
#      listing_id         date available    price adjusted_price  \
# 0            958  04-09-2024         t  $170.00            NaN
# 1            958  05-09-2024         f  $170.00            NaN
# 2            958  06-09-2024         f  $170.00            NaN
# 3            958  07-09-2024         f  $170.00            NaN
# 4            958  08-09-2024         f  $170.00            NaN
# ..           ...         ...       ...      ...            ...
# 995         8142  27-05-2025         t   $65.00            NaN
# 996         8142  28-05-2025         t   $65.00            NaN
# 997         8142  29-05-2025         t   $65.00            NaN
# 998         8142  30-05-2025         t   $65.00            NaN
# 999         8142  31-05-2025         t   $65.00            NaN
#
#      minimum_nights  maximum_nights  available_unit            id  \
# 0                 2            1125               8  2.648800e+04
# 1                 2            1125               6  6.392525e+17
# ...

# %%
merged_df.to_csv('merged_output.csv')
