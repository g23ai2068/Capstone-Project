# %% [markdown]
# <a href="https://colab.research.google.com/github/g23ai2068/Capstone-Project/blob/g23ai2125_Sudherson/Airbnb_capstone_project_Phase_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = str(input('whats this notebook is for:' ))
print('this notebook is for',name)
# Out:
# whats this notebook is for:Capstone project
# this notebook is for Capstone project

# %% [markdown]
# ##Phase 1
#
# #Problem 1
# * Exploratory Data Analysis for the Airbnb Data containing ('Calender.csv, reviews.csv, Listing.csv')

# %% [markdown]
# Making the required packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
calender_df=pd.read_csv('/content/calendar.csv')

# %%
reviews_one=pd.read_csv('/content/review (1).csv')
reviews=pd.read_csv('/content/reviews.csv')
Total_reviews=reviews.merge(reviews_one, how='right')
Total_reviews.head(3)
# Out:
#    listing_id       id        date  reviewer_id reviewer_name  \
# 0         958   5977.0  2009-07-23      15695.0      Edmund C
# 1         958   6660.0  2009-08-03      26145.0         Simon
# 2         958  11519.0  2009-09-27      25839.0         Denis
#
#                                             comments
# 0  Our experience was, without a doubt, a five st...
# 1  Returning to San Francisco is a rejuvenating t...
# 2  We were very pleased with the accommodations a...

# %%
Total_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273968 entries, 0 to 273967
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   listing_id     273968 non-null  int64
#  1   id             273967 non-null  float64
#  2   date           273968 non-null  object
#  3   reviewer_id    273967 non-null  float64
#  4   reviewer_name  273964 non-null  object
#  5   comments       273926 non-null  object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 12.5+ MB

# %%
listing_one=pd.read_csv('/content/listing (1).csv')
listings=pd.read_csv('/content/listings.csv')
Total=[listings,listing_one]
Total_listing=pd.concat(Total)
Total_listing.head(3)
# Out:
#                    id                                      listing_url  \
# 0            50489368            https://www.airbnb.com/rooms/50489368
# 1            53687935            https://www.airbnb.com/rooms/53687935
# 2  623833252305593889  https://www.airbnb.com/rooms/623833252305593889
#
#       scrape_id last_scraped           source  \
# 0  2.024090e+13   2024-09-04  previous scrape
# 1  2.024090e+13   2024-09-04  previous scrape
# 2  2.024090e+13   2024-09-04      city scrape
#
#                                                 name  \
# 0  (B) Furnished Efficiency Studio near Union Square
# 1   2 Private Rooms in SF. Walk to Bart. Modern Home
# 2         Massive 1-bedroom condo in the heart of SF
#
#                                          description  \
# 0  This special place is close to everything, mak...
# 1  Enjoy a stylish and zen experience at this mod...
# 2  Spacious 1-bed 1-bath condo in downtown SF nea...
#
#          neighborhood_overview  \
# ...

# %%
Total_listing.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
# ...

# %%
Total_listing.columns.value_counts()
# Out:
# id                           1
# maximum_nights_avg_ntm       1
# calendar_last_scraped        1
# availability_365             1
# availability_90              1
#                             ..
# host_verifications           1
# host_total_listings_count    1
# host_listings_count          1
# host_neighbourhood           1
# neighbourhood_group          1
# Name: count, Length: 76, dtype: int64

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7807 entries, 0 to 7806
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            7807 non-null   int64
#  1   listing_url                                   7807 non-null   object
#  2   scrape_id                                     7807 non-null   int64
#  3   last_scraped                                  7807 non-null   object
#  4   source                                        7807 non-null   object
#  5   name                                          7807 non-null   object
#  6   description                                   7632 non-null   object
#  7   neighborhood_overview                         5107 non-null   object
#  8   picture_url                                   7807 non-null   object
# ...

# %%
listing_one.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7807 entries, 0 to 7806
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              7807 non-null   int64
#  1   name                            7807 non-null   object
#  2   host_id                         7807 non-null   int64
#  3   host_name                       7807 non-null   object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   7807 non-null   object
#  6   latitude                        7807 non-null   float64
#  7   longitude                       7807 non-null   float64
#  8   room_type                       7807 non-null   object
#  9   price                           6158 non-null   float64
#  10  minimum_nights                  7807 non-null   int64
#  11  number_of_reviews               7807 non-null   int64
# ...

# %%
pip install nltk

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import re

# %%
df = pd.read_csv('/content/reviews.csv', usecols=['comments'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392959 entries, 0 to 392958
# Data columns (total 1 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   comments  392889 non-null  object
# dtypes: object(1)
# memory usage: 3.0+ MB

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392959 entries, 0 to 392958
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   listing_id     392959 non-null  int64
#  1   id             392959 non-null  int64
#  2   date           392959 non-null  object
#  3   reviewer_id    392959 non-null  int64
#  4   reviewer_name  392956 non-null  object
#  5   comments       392889 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 18.0+ MB

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
lemma = WordNetLemmatizer()
stop_words = stopwords.words('english')
sent = SentimentIntensityAnalyzer()

# %%
import string

# %%
df['comments'] = df['comments'].astype(str)

# %%
polarity = [round(sent.polarity_scores(i)['compound'], 2) for i in df['comments']]
df['sentiment_score'] = polarity
df.head()
# Out:
#                                             comments  sentiment_score
# 0  Our experience was, without a doubt, a five st...             0.96
# 1  Returning to San Francisco is a rejuvenating t...             0.98
# 2  We were very pleased with the accommodations a...             0.76
# 3  We highly recommend this accomodation and agre...             0.98
# 4  Holly's place was great. It was exactly what I...             0.96

# %%
df['sentiment_score'].unique()
# Out:
# array([ 0.96,  0.98,  0.76,  0.99,  0.97,  0.9 ,  0.93,  0.94,  1.  ,
#         0.95,  0.  ,  0.78,  0.92,  0.91,  0.82,  0.87,  0.48,  0.8 ,
#         0.71,  0.46,  0.79,  0.85,  0.4 ,  0.77,  0.88,  0.89,  0.59,
#         0.86,  0.49,  0.67,  0.64, -0.6 ,  0.08,  0.84,  0.72, -0.56,
#         0.83, -0.13,  0.81,  0.61,  0.54,  0.62,  0.68, -0.3 ,  0.29,
#         0.57,  0.66,  0.7 ,  0.2 , -0.48,  0.69,  0.74,  0.51,  0.27,
#         0.56,  0.39,  0.42,  0.73,  0.32,  0.44,  0.55,  0.5 , -0.64,
#         0.03,  0.02,  0.75,  0.43, -0.2 , -0.58, -0.42,  0.65, -0.91,
#        -0.53, -0.93,  0.22,  0.58, -0.95,  0.53, -0.8 , -0.78, -0.73,
#         0.3 ,  0.1 , -0.18,  0.6 ,  0.47, -0.52,  0.36, -0.08, -0.54,
#        -0.17, -0.33,  0.52, -0.83, -0.46, -0.27, -0.43, -0.32,  0.23,
#        -0.36, -0.05, -0.57,  0.34, -0.99, -0.26,  0.38,  0.28,  0.63,
#         0.25, -0.94, -0.34,  0.11, -0.11,  0.18, -0.09, -0.25, -0.07,
# ...

# %%
def text_prep(x):
     corp = str(x).lower()
     corp = re.sub('[^a-zA-Z]+',' ', corp).strip()
     tokens = word_tokenize(corp)
     words = [t for t in tokens if t not in stop_words]
     lemmatize = [lemma.lemmatize(w) for w in words]

     return lemmatize

# %%
preprocess_tag = [text_prep(i) for i in df['comments']]
df["preprocess_txt"] = preprocess_tag

# %%
calender1=pd.read_csv('/content/calendar.csv')
calender1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55389 entries, 0 to 55388
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   listing_id      55389 non-null  int64
#  1   date            55389 non-null  object
#  2   available       55389 non-null  object
#  3   price           55389 non-null  object
#  4   adjusted_price  0 non-null      float64
#  5   minimum_nights  55388 non-null  float64
#  6   maximum_nights  55388 non-null  float64
#  7   available_unit  55388 non-null  float64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 3.4+ MB

# %%
calender1['price'].head(10)
# Out:
# 0    $170.00
# 1    $170.00
# 2    $170.00
# 3    $170.00
# 4    $170.00
# 5    $170.00
# 6    $170.00
# 7    $170.00
# 8    $170.00
# 9    $170.00
# Name: price, dtype: object

# %%
T1=Total_reviews.fillna(method='bfill')
# Out:
# <ipython-input-28-24528cc7a06c>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   T1=Total_reviews.fillna(method='bfill')

# %%
T1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273968 entries, 0 to 273967
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   listing_id     273968 non-null  int64
#  1   id             273967 non-null  float64
#  2   date           273968 non-null  object
#  3   reviewer_id    273967 non-null  float64
#  4   reviewer_name  273967 non-null  object
#  5   comments       273967 non-null  object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 12.5+ MB

# %%
Total_reviews.tail()
# Out:
#         listing_id            id        date  reviewer_id reviewer_name  \
# 273963    31858008  9.211366e+17  2023-06-24  434442679.0      Savannah
# 273964    31858008  9.356479e+17  2023-07-14  471319065.0      Danielle
# 273965    31858008  9.377952e+17  2023-07-17  520849594.0          Ryan
# 273966    31858008  9.508611e+17  2023-08-04  359424296.0      Baptiste
# 273967    31924784           NaN          20          NaN           NaN
#
#                                                  comments
# 273963  Fei is one of my favorite hosts ever. She alwa...
# 273964  If you just need one night close to SFO, it's ...
# 273965  Very pleased with my stay. Fei was very respon...
# 273966  bon séjour chez Fei, seul problème : il n'y pa...
# 273967                                                NaN

# %%
Total_reviews[Total_reviews['reviewer_name'].isin(['Nan'])]
# Out:
#         listing_id            id        date  reviewer_id reviewer_name  \
# 9380        109883  7.386024e+17  2022-10-15   38168192.0           Nan
# 9655        114401  6.573972e+07  2016-03-16   41699479.0           Nan
# 11542       183859  6.980079e+06  2013-09-02    2216772.0           Nan
# 22277       465723  7.087978e+08  2020-11-14   38168192.0           Nan
# 56192      1605483  5.078601e+07  2015-10-14   44957173.0           Nan
# 56689      1623609  2.335624e+07  2014-11-30   17014923.0           Nan
# 58964      1725853  3.528440e+08  2018-11-25   38168192.0           Nan
# 59141      1738415  2.049621e+07  2014-09-30    1414602.0           Nan
# 75501      2518781  6.116533e+08  2020-02-27    2126669.0           Nan
# 75924      2538807  6.116009e+17  2022-04-23  154627043.0           Nan
# 90299      3759368  7.515437e+07  2016-05-19   59730258.0           Nan
# 96476      4252808  7.341012e+08  2021-02-24   38168192.0           Nan
# ...

# %%
Total_reviews.shape
# Out:
# (273968, 6)

# %%
T1[T1['id'].isin([738602352949893620])]
# Out:
# Empty DataFrame
# Columns: [listing_id, id, date, reviewer_id, reviewer_name, comments]
# Index: []

# %%
T1['reviewer_name'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 273968 entries, 0 to 273967
# Series name: reviewer_name
# Non-Null Count   Dtype
# --------------   -----
# 273967 non-null  object
# dtypes: object(1)
# memory usage: 2.1+ MB

# %%
Total_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273968 entries, 0 to 273967
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   listing_id     273968 non-null  int64
#  1   id             273967 non-null  float64
#  2   date           273968 non-null  object
#  3   reviewer_id    273967 non-null  float64
#  4   reviewer_name  273964 non-null  object
#  5   comments       273926 non-null  object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 12.5+ MB

# %%
Total_reviews[Total_reviews['comments'].isin(['Nan'])]
# Out:
# Empty DataFrame
# Columns: [listing_id, id, date, reviewer_id, reviewer_name, comments]
# Index: []

# %%
pd.isnull(Total_reviews).sum()
# Out:
# listing_id        0
# id                1
# date              0
# reviewer_id       1
# reviewer_name     4
# comments         42
# dtype: int64

# %%
T1=Total_reviews.dropna(subset=['reviewer_name','comments'])

# %%
T1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 273923 entries, 0 to 273966
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   listing_id     273923 non-null  int64
#  1   id             273923 non-null  float64
#  2   date           273923 non-null  object
#  3   reviewer_id    273923 non-null  float64
#  4   reviewer_name  273923 non-null  object
#  5   comments       273923 non-null  object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 14.6+ MB

# %%
T1.columns
# Out:
# Index(['listing_id', 'id', 'date', 'reviewer_id', 'reviewer_name', 'comments'], dtype='object')

# %%
Total_listing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15614 entries, 0 to 7806
# Data columns (total 76 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            15614 non-null  int64
#  1   listing_url                                   7807 non-null   object
#  2   scrape_id                                     7807 non-null   float64
#  3   last_scraped                                  7807 non-null   object
#  4   source                                        7807 non-null   object
#  5   name                                          15614 non-null  object
#  6   description                                   7632 non-null   object
#  7   neighborhood_overview                         5107 non-null   object
#  8   picture_url                                   7807 non-null   object
# ...

# %%
Total_listing.dropna()
# Out:
# Empty DataFrame
# ...

# %%
listin=Total_listing[['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'host_id',
'host_name', 'host_since', 'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
'number_of_reviews', 'review_scores_rating', 'instant_bookable']]

# %%
listin.head()
# Out:
#                    id                                      listing_url  \
# 0            50489368            https://www.airbnb.com/rooms/50489368
# 1            53687935            https://www.airbnb.com/rooms/53687935
# 2  623833252305593889  https://www.airbnb.com/rooms/623833252305593889
# 3            53817024            https://www.airbnb.com/rooms/53817024
# 4            54381390            https://www.airbnb.com/rooms/54381390
#
#       scrape_id last_scraped  \
# 0  2.024090e+13   2024-09-04
# 1  2.024090e+13   2024-09-04
# 2  2.024090e+13   2024-09-04
# 3  2.024090e+13   2024-09-04
# 4  2.024090e+13   2024-09-04
#
#                                                 name    host_id  host_name  \
# 0  (B) Furnished Efficiency Studio near Union Square  190158687  Christine
# 1   2 Private Rooms in SF. Walk to Bart. Modern Home  433577666     Hossna
# 2         Massive 1-bedroom condo in the heart of SF    2180153     Duolin
# ...

# %%
listin.describe()
# Out:
#                  id     scrape_id       host_id      latitude     longitude  \
# count  1.561400e+04  7.807000e+03  1.561400e+04  15614.000000  15614.000000
# mean   3.947473e+17  2.024090e+13  1.583469e+08     37.769485   -122.429948
# std    4.729429e+17  2.582197e+00  1.898592e+08      0.023051      0.026964
# min    9.580000e+02  2.024090e+13  1.169000e+03     37.708540   -122.512460
# 25%    2.280397e+07  2.024090e+13  7.197110e+06     37.754360   -122.442225
# 50%    4.921290e+07  2.024090e+13  5.835076e+07     37.774900   -122.421934
# 75%    8.833529e+17  2.024090e+13  2.930250e+08     37.788415   -122.410992
# max    1.237237e+18  2.024090e+13  5.993102e+08     37.810943   -122.366043
#
#        number_of_reviews  review_scores_rating
# count       15614.000000           6036.000000
# mean           50.334187              4.787391
# std           106.159972              0.400233
# min             0.000000              1.000000
# ...

# %%
listin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15614 entries, 0 to 7806
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    15614 non-null  int64
#  1   listing_url           7807 non-null   object
#  2   scrape_id             7807 non-null   float64
#  3   last_scraped          7807 non-null   object
#  4   name                  15614 non-null  object
#  5   host_id               15614 non-null  int64
#  6   host_name             15614 non-null  object
#  7   host_since            7807 non-null   object
#  8   neighbourhood         12914 non-null  object
#  9   latitude              15614 non-null  float64
#  10  longitude             15614 non-null  float64
#  11  room_type             15614 non-null  object
#  12  price                 12316 non-null  object
#  13  number_of_reviews     15614 non-null  int64
#  14  review_scores_rating  6036 non-null   float64
# ...

# %%
listin.shape
# Out:
# (15614, 16)

# %%
pd.isnull(listin).sum()
# Out:
# id                         0
# listing_url             7807
# scrape_id               7807
# last_scraped            7807
# name                       0
# host_id                    0
# host_name                  0
# host_since              7807
# neighbourhood           2700
# latitude                   0
# longitude                  0
# room_type                  0
# price                   3298
# number_of_reviews          0
# review_scores_rating    9578
# instant_bookable        7807
# dtype: int64

# %%
listin_1=listin.dropna()

# %%
listin_1.describe()
# Out:
#                  id     scrape_id       host_id     latitude    longitude  \
# count  3.438000e+03  3.438000e+03  3.438000e+03  3438.000000  3438.000000
# mean   2.239980e+17  2.024090e+13  1.127400e+08    37.765682  -122.434033
# std    3.782818e+17  1.480684e+00  1.578982e+08     0.023276     0.028572
# min    9.580000e+02  2.024090e+13  1.169000e+03    37.708540  -122.512110
# 25%    1.466273e+07  2.024090e+13  4.582677e+06    37.749945  -122.447162
# 50%    3.629814e+07  2.024090e+13  2.729137e+07    37.766336  -122.427495
# 75%    5.870195e+17  2.024090e+13  1.579992e+08    37.785651  -122.412601
# max    1.208638e+18  2.024090e+13  5.891960e+08    37.809540  -122.370470
#
#        number_of_reviews  review_scores_rating
# count        3438.000000           3438.000000
# mean           89.453461              4.800183
# std           134.829797              0.367224
# min             1.000000              1.000000
# 25%             7.000000              4.780000
# ...

# %%
listin_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3438 entries, 8 to 7806
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    3438 non-null   int64
#  1   listing_url           3438 non-null   object
#  2   scrape_id             3438 non-null   float64
#  3   last_scraped          3438 non-null   object
#  4   name                  3438 non-null   object
#  5   host_id               3438 non-null   int64
#  6   host_name             3438 non-null   object
#  7   host_since            3438 non-null   object
#  8   neighbourhood         3438 non-null   object
#  9   latitude              3438 non-null   float64
#  10  longitude             3438 non-null   float64
#  11  room_type             3438 non-null   object
#  12  price                 3438 non-null   object
#  13  number_of_reviews     3438 non-null   int64
#  14  review_scores_rating  3438 non-null   float64
# ...

# %%
print(listin['price'].unique())
# Out:
# [nan '$132.00' '$78.00' ... 1900.0 616.0 424.0]

# %% [markdown]
# ##Data quality visualizations
#
# Data quality visualizations are graphical representations of your data quality dimensions that can help you to
# spot anomalies,
# outliers,
# errors,
# missing values,
# duplicates, or inconsistencies.
#
# Histograms, illustrate the distribution of data values and can help to identify
# #skewness outliers, or gaps.
#
# Box plots show summary statistics such as the median, quartiles, and whiskers and can help to identify outliers, variability, or asymmetry.
#
# Scatter plots display the relationship between two variables and can help to identify correlation, outliers, or clusters.
#
# Heat maps reveal the intensity of a variable across a matrix of categories and can assist in identifying patterns, trends, or anomalies.
#
# Bar charts present the frequency or proportion of a categorical variable and can help to identify imbalances, missing values, or duplicates.

# %% [markdown]
# Planned to make the usage of Histograms
# BoxPlots (Mean Median for the distribution)
# Scatter Plots (Listing data set)
# Heat Maps (Reviews, Listings and Calender)
# Bar chart

# %%
T1.columns
# Out:
# Index(['listing_id', 'id', 'date', 'reviewer_id', 'reviewer_name', 'comments'], dtype='object')

# %%
T1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 273923 entries, 0 to 273966
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   listing_id     273923 non-null  int64
#  1   id             273923 non-null  float64
#  2   date           273923 non-null  object
#  3   reviewer_id    273923 non-null  float64
#  4   reviewer_name  273923 non-null  object
#  5   comments       273923 non-null  object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 14.6+ MB

# %%
listin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15614 entries, 0 to 7806
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    15614 non-null  int64
#  1   listing_url           7807 non-null   object
#  2   scrape_id             7807 non-null   float64
#  3   last_scraped          7807 non-null   object
#  4   name                  15614 non-null  object
#  5   host_id               15614 non-null  int64
#  6   host_name             15614 non-null  object
#  7   host_since            7807 non-null   object
#  8   neighbourhood         12914 non-null  object
#  9   latitude              15614 non-null  float64
#  10  longitude             15614 non-null  float64
#  11  room_type             15614 non-null  object
#  12  price                 12316 non-null  object
#  13  number_of_reviews     15614 non-null  int64
#  14  review_scores_rating  6036 non-null   float64
# ...

# %%
print('Working on the visualization part')
# Out:
# Working on the visualization part

# %%
calender=pd.read_csv('/content/calendar.csv')
calender.head(2)
# Out:
#    listing_id         date available    price  adjusted_price  minimum_nights  \
# 0          958  04-09-2024         t  $170.00             NaN             2.0
# 1          958  05-09-2024         f  $170.00             NaN             2.0
#
#    maximum_nights  available_unit
# 0          1125.0             8.0
# 1          1125.0             6.0

# %%
calender1=calender.drop('adjusted_price',axis=1)

# %%
calender1.shape
# Out:
# (55389, 7)

# %%
calender1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55389 entries, 0 to 55388
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   listing_id      55389 non-null  int64
#  1   date            55389 non-null  object
#  2   available       55389 non-null  object
#  3   price           55389 non-null  object
#  4   minimum_nights  55388 non-null  float64
#  5   maximum_nights  55388 non-null  float64
#  6   available_unit  55388 non-null  float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 3.0+ MB

# %%
calender1.shape
# Out:
# (55389, 7)

# %%
calender2=calender1.dropna()

# %%
calender2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 55388 entries, 0 to 55387
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   listing_id      55388 non-null  int64
#  1   date            55388 non-null  object
#  2   available       55388 non-null  object
#  3   price           55388 non-null  object
#  4   minimum_nights  55388 non-null  float64
#  5   maximum_nights  55388 non-null  float64
#  6   available_unit  55388 non-null  float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 3.4+ MB

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x=calender2['available'],y=calender2['minimum_nights'])
plt.title("min_nights_tospend", size=15, weight='bold')
plt.xlabel("room_available", size=13)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x=calender2['available'],y=calender2['maximum_nights'])
plt.title("max_nights_tospend", size=15, weight='bold')
plt.xlabel("room_available", size=10)
plt.show()

# %%
 #Scatterplot for Room Type vs Price
plt.figure(figsize=(12,8))
sns.scatterplot(x='date', y='price', data=calender2, alpha=0.7)# alpha adds transparency
plt.xticks(rotation=90)
plt.xlabel("Room Type", size=13)
plt.ylabel("Price", size=13)
plt.title("Room Type vs Price", size=15, weight='bold')
plt.show()

# %%
#reviews data visualization
