# %% [markdown]
# <a href="https://colab.research.google.com/github/g23ai2068/Capstone-Project/blob/g23ai2125_Sudherson/CTGan_Reviews_and_Calender_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello_world')
# Out:
# hello_world

# %%
pip install tensorflow

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
import pandas as pd
import io
import os
import requests
import numpy as np
from sklearn import metrics

# %%
import chardet

# %%
with open ('/content/reviews.csv','rb')as f:result=chardet.detect(f.read())
df=pd.read_csv('/content/reviews.csv',encoding=result['utf-8'])
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-2c748b85f384> in <cell line: 2>()
#       1 with open ('/content/reviews.csv','rb')as f:result=chardet.detect(f.read())
# ----> 2 df=pd.read_csv('/content/reviews.csv',encoding=result['utf-8'])
#       3 df.head()
#
# KeyError: 'utf-8'

# %%
df2=pd.read_csv('/content/listings.csv')
df2.head()
# Out:
#                    id                                      listing_url  \
# 0            50489368            https://www.airbnb.com/rooms/50489368
# 1            53687935            https://www.airbnb.com/rooms/53687935
# 2  623833252305593889  https://www.airbnb.com/rooms/623833252305593889
# 3            53817024            https://www.airbnb.com/rooms/53817024
# 4            54381390            https://www.airbnb.com/rooms/54381390
#
#         scrape_id last_scraped           source  \
# 0  20240904163718   2024-09-04  previous scrape
# 1  20240904163718   2024-09-04  previous scrape
# 2  20240904163718   2024-09-04      city scrape
# 3  20240904163718   2024-09-04  previous scrape
# 4  20240904163718   2024-09-04  previous scrape
#
#                                                 name  \
# 0  (B) Furnished Efficiency Studio near Union Square
# 1   2 Private Rooms in SF. Walk to Bart. Modern Home
# 2         Massive 1-bedroom condo in the heart of SF
# ...

# %%
df2.shape
# Out:
# (7807, 75)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
import pandas as pd
import io
import os
import requests
import numpy as np
from sklearn import metrics

# %%
df2=pd.read_csv('/content/listings.csv',na_values=['NA', '?','Nan','NaN'])
df2.head()
# Out:
#                    id                                      listing_url  \
# 0            50489368            https://www.airbnb.com/rooms/50489368
# 1            53687935            https://www.airbnb.com/rooms/53687935
# 2  623833252305593889  https://www.airbnb.com/rooms/623833252305593889
# 3            53817024            https://www.airbnb.com/rooms/53817024
# 4            54381390            https://www.airbnb.com/rooms/54381390
#
#         scrape_id last_scraped           source  \
# 0  20240904163718   2024-09-04  previous scrape
# 1  20240904163718   2024-09-04  previous scrape
# 2  20240904163718   2024-09-04      city scrape
# 3  20240904163718   2024-09-04  previous scrape
# 4  20240904163718   2024-09-04  previous scrape
#
#                                                 name  \
# 0  (B) Furnished Efficiency Studio near Union Square
# 1   2 Private Rooms in SF. Walk to Bart. Modern Home
# 2         Massive 1-bedroom condo in the heart of SF
# ...

# %%
df2.shape
# Out:
# (7807, 75)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7807 entries, 0 to 7806
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            7807 non-null   int64
#  1   listing_url                                   7807 non-null   object
#  2   scrape_id                                     7807 non-null   int64
#  3   last_scraped                                  7807 non-null   object
#  4   source                                        7807 non-null   object
#  5   name                                          7807 non-null   object
#  6   description                                   7632 non-null   object
#  7   neighborhood_overview                         5107 non-null   object
#  8   picture_url                                   7807 non-null   object
# ...

# %%
COLS_USED = ['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'host_id', 'host_name', 'host_since', 'neighbourhood', 'latitude', 'longitude', 'room_type', 'price', 'number_of_reviews', 'review_scores_rating', 'instant_bookable']
COLS_USED = ['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'host_id', 'host_name', 'host_since', 'neighbourhood', 'latitude', 'longitude', 'room_type', 'price', 'number_of_reviews', 'review_scores_rating', 'instant_bookable']

# %%
df = df2[COLS_USED]

# %%
df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'host_id',
#        'host_name', 'host_since', 'neighbourhood', 'latitude', 'longitude',
#        'room_type', 'price', 'number_of_reviews', 'review_scores_rating',
#        'instant_bookable'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7807 entries, 0 to 7806
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    7807 non-null   int64
#  1   listing_url           7807 non-null   object
#  2   scrape_id             7807 non-null   int64
#  3   last_scraped          7807 non-null   object
#  4   name                  7807 non-null   object
#  5   host_id               7807 non-null   int64
#  6   host_name             7807 non-null   object
#  7   host_since            7807 non-null   object
#  8   neighbourhood         5107 non-null   object
#  9   latitude              7807 non-null   float64
#  10  longitude             7807 non-null   float64
#  11  room_type             7807 non-null   object
#  12  price                 6158 non-null   object
#  13  number_of_reviews     7807 non-null   int64
#  14  review_scores_rating  6036 non-null   float64
# ...

# %%
#Handling missing values in the Price column
import matplotlib.pyplot as plt

df['price'].describe()
# Out:
# count        6158
# unique        609
# top       $113.00
# freq          211
# Name: price, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from faker import Faker
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-31-b0f84e213bc5> in <cell line: 2>()
#       1 from sklearn.preprocessing import LabelEncoder, MinMaxScaler
# ----> 2 from faker import Faker
#
# ModuleNotFoundError: No module named 'faker'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
df_x_train, df_x_test, df_y_train, df_y_test = train_test_split(
    df.drop('price',axis =1),
    df['price'],
    test_size=0.20,
    random_state=42,
)
df_x_test, df_y_test = df_x_test.reset_index(drop=True), \
  df_y_test.reset_index(drop=True)
df_y_train = pd.DataFrame(df_y_train)
df_y_test = pd.DataFrame(df_y_test)

# %%
# Pandas to Numpy
x_train = df_x_train.values
x_test = df_x_test.values
y_train = df_y_train.values
y_test = df_y_test.values

# %%
model = Sequential()

# %%
model.add(Dense(50, input_dim=x_train.shape[1], activation='relu'))
model.add(Dense(25, activation='relu')) # Hidden 2
model.add(Dense(12, activation='relu')) # Hidden 2
model.add(Dense(1)) # Output
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3,
        patience=5, verbose=1, mode='auto',
        restore_best_weights=True)
model.fit(x_train,y_train,validation_data=(x_test,y_test),
        callbacks=[monitor], verbose=2,epochs=1000)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-87a54df2cae4> in <cell line: 4>()
#       2         patience=5, verbose=1, mode='auto',
#       3         restore_best_weights=True)
# ----> 4 model.fit(x_train,y_train,validation_data=(x_test,y_test),
#       5         callbacks=[monitor], verbose=2,epochs=1000)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
# ...

# %%
pip install sdv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.3/152.3 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 12.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 48.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.4/52.4 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.7/174.7 kB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 48.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.6/82.6 kB 6.3 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

# %%
from sdv.metadata import SingleTableMetadata
from sdv.single_table import CTGANSynthesizer

# %%
data=pd.read_csv('/content/listings.csv')
data.head()
# Out:
#                    id                                      listing_url  \
# 0            50489368            https://www.airbnb.com/rooms/50489368
# 1            53687935            https://www.airbnb.com/rooms/53687935
# 2  623833252305593889  https://www.airbnb.com/rooms/623833252305593889
# 3            53817024            https://www.airbnb.com/rooms/53817024
# 4            54381390            https://www.airbnb.com/rooms/54381390
#
#         scrape_id last_scraped           source  \
# 0  20240904163718   2024-09-04  previous scrape
# 1  20240904163718   2024-09-04  previous scrape
# 2  20240904163718   2024-09-04      city scrape
# 3  20240904163718   2024-09-04  previous scrape
# 4  20240904163718   2024-09-04  previous scrape
#
#                                                 name  \
# 0  (B) Furnished Efficiency Studio near Union Square
# 1   2 Private Rooms in SF. Walk to Bart. Modern Home
# 2         Massive 1-bedroom condo in the heart of SF
# ...

# %%
data.shape
# Out:
# (7807, 75)

# %%
metadata=SingleTableMetadata()
metadata.detect_from_dataframe(data)

# %%
synthesizer=CTGANSynthesizer(metadata,epochs=500,verbose=True)
synthesizer.fit(data)
# Out:
# /usr/local/lib/python3.10/dist-packages/sdv/single_table/base.py:120: FutureWarning: The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
#   warnings.warn(DEPRECATION_MSG, FutureWarning)
# /usr/local/lib/python3.10/dist-packages/sdv/single_table/base.py:105: UserWarning: We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#   warnings.warn(
# PerformanceAlert: Using the CTGANSynthesizer on this data is not recommended. To model this data, CTGAN will generate a large number of columns.
#
# Original Column Name                         Est # of Columns (CTGAN)
# scrape_id                                    1
# last_scraped                                 11
# source                                       2
# host_id                                      11
# host_since                                   11
# host_location                                230
# ...

# %%
synthetic_data=synthesizer.sample(num_rows=1000)

# %%
synthetic_data.shape
# Out:
# (1000, 75)

# %%
synthetic_data.to_csv('Synthetic_data',index=False)

# %%
S_data = pd.read_csv('/content/Synthetic_data')

# %%
S_data.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
# ...

# %%
data2=pd.read_csv('/content/calendar.csv')
# Out:
# <ipython-input-15-0ff4c91efc1d>:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data2=pd.read_csv('/content/calendar.csv')

# %%
metadata2=SingleTableMetadata()
metadata2.detect_from_dataframe(data2)

# %%
synthesizer2=CTGANSynthesizer(metadata2,epochs=500,verbose=True)
synthesizer2.fit(data2)
# Out:
# /usr/local/lib/python3.10/dist-packages/sdv/single_table/base.py:120: FutureWarning: The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
#   warnings.warn(DEPRECATION_MSG, FutureWarning)
# ---------------------------------------------------------------------------
# TerminatedWorkerError                     Traceback (most recent call last)
# <ipython-input-18-aa38f42188e4> in <cell line: 2>()
#       1 synthesizer2=CTGANSynthesizer(metadata2,epochs=500,verbose=True)
# ----> 2 synthesizer2.fit(data2)
#
# /usr/local/lib/python3.10/dist-packages/sdv/single_table/base.py in fit(self, data)
#     504         self._random_state_set = False
#     505         processed_data = self.preprocess(data)
# --> 506         self.fit_processed_data(processed_data)
#     507
#     508     def _validate_fit_before_save(self):
#
# /usr/local/lib/python3.10/dist-packages/sdv/single_table/base.py in fit_processed_data(self, processed_data)
# ...
